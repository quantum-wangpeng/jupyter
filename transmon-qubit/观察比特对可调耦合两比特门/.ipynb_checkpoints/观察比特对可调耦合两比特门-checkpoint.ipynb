# %% [markdown]
# # 环境导入

# %%
import sys
sys.path.append('F:/wangpeng/code/transmon-qubit/')
sys.executable
# Out:
# 'C:\\Users\\QuanmtumYangxx\\anaconda3\\envs\\transmon-qubit\\python.exe'

# %%
from matplotlib import pyplot as plt
import numpy as np
import qutip as qp
from sklearn.metrics import mean_squared_error
import copy
from chip_hamiltonian.chip_hamiltonian import Chip, ChipDynamic
from solvers.solvers import Solver, SolverDynamic
from experiment import *
from pulse.pulse_lib import *
from functions.plot_tools import PlotTool
from functions.fit_tools import fit_fft
from functions import *
from functions.tools import *

# %matplotlib notebook
np.set_printoptions(threshold=np.inf, precision=4, suppress=True)

yaml_path = r'.\chip_param.yaml'
ploter = PlotTool(figsize=(8,5), cmap='cividis', flag_save=True)

# %% [markdown]
# # 初始化

# %%
chip = Solver(yaml_path, 3)
w2_work0, E_diff = chip.resonate_point('Q2', (4.7, 4.9), (('Q1', 'Q2'), (1, 1)), (('Q1', 'Q2'), (0, 2)))

# %%
cz = CZ(yaml_path, 3, QL='Q1', QH='Q2', flag_fig=True)
# Out:
# root_path: CZ

# %%
w2_list = w2_work0 + np.linspace(-0.05, 0.05, 51)
wc_list = np.linspace(4.8, 5.6, 61)
arg_list_dic = {'Q2': w2_list, 'C1_2': wc_list}
cz.scan2d_leak(arg_list_dic, 30)

# %%
cz.analyze2d_leak(['Q2', 'C1_2'])
# Out:
# <img src="data:image/png;base64,..." width="960">
# fig path: F:\wangpeng\code\jupyter\transmon-qubit\观察比特对可调耦合两比特门\CZ\2023-03\0316-17.36.13_CZ Leakage.png
